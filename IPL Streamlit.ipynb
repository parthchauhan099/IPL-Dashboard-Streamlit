# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 357.8 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.3 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 104.155.197.42

# %%
# !streamlit run '/content/drive/MyDrive/Model Deploy/IPL DataAnalysis/app.py' & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.155.197.42:8501
#
# ⠴⠦⠧⠇⠏⠋your url is: https://cuddly-ducks-stay.loca.lt
# y
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/elements/lib/image_utils.py:282 in
#   image_to_url
# ────────────────────────────────────────────────────────────────────────────────────────
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ML -
# Dataset/Cricket/ipl-logo.jpg'
#
# During handling of the above exception, another exception occurred:
#
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/memory_media_file_storage.
#   py:164 in _read_file
# ...

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('/content/drive/MyDrive/Model Deploy/IPL DataAnalysis/ipl-logo.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2838705471.py in <cell line: 0>()
#       1 img = plt.imread('/content/drive/MyDrive/Model Deploy/IPL DataAnalysis/ipl-logo.jpg')
# ----> 2 img.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'
